# %% [markdown]
# # This program uses an artificial recurrent neural network called Long Short Term Memory

# %% [markdown]
# ## We predict the closing stock price of a corporation (Apple Inc.) using the past 60 days data.

# %% [markdown]
# #### Importing the libraries

# %%
import pandas as pd
import math
import numpy as np
import pandas_datareader as web
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Get the Stock Quote

# %%
df = web.DataReader('AAPL', data_source = 'yahoo', start = '2012-01-01', end = '2019-12-30')
#Show the data
df
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732142  14.607142  14.621428  14.686786  302220800.0  12.669562
# 2012-01-04  14.810000  14.617143  14.642858  14.765715  260022000.0  12.737655
# 2012-01-05  14.948215  14.738214  14.819643  14.929643  271269600.0  12.879071
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  13.013705
# 2012-01-09  15.276786  15.048214  15.196428  15.061786  394024400.0  12.993064
# ...               ...        ...        ...        ...          ...        ...
# 2019-12-23  71.062500  70.092499  70.132500  71.000000   98572000.0  70.392090
# 2019-12-24  71.222504  70.730003  71.172501  71.067497   48478800.0  70.459007
# 2019-12-26  72.495003  71.175003  71.205002  72.477501   93121200.0  71.856941
# 2019-12-27  73.492500  72.029999  72.779999  72.449997  146266000.0  71.829674
# 2019-12-30  73.172501  71.305000  72.364998  72.879997  144114400.0  72.255997
#
# [2011 rows x 6 columns]

# %%
df.shape
# Out:
# (2011, 6)

# %% [markdown]
# #### Visualize closing price history

# %%
plt.figure(figsize = (16, 8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price $', fontsize=18)
plt.show()

# %% [markdown]
# #### Create new Dataframe and convert to Array

# %%
data = df.filter(['Close'])
dataset = data.values
training_data_len = math.ceil(len(dataset) * 0.8)
training_data_len
# Out:
# 1609

# %% [markdown]
# #### Scale the data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01254461],
#        [0.01388393],
#        [0.01666555],
#        ...,
#        [0.99317021],
#        [0.99270351],
#        [1.        ]])

# %% [markdown]
# ### Create the training dataset

# %% [markdown]
# #### Create the scaled training dataset

# %%
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60: i, 0])
    y_train.append(train_data[i, 0])
    if i <= 61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.01254461, 0.01388393, 0.01666555, 0.01931386, 0.01890783,
#        0.01982291, 0.01940476, 0.01870178, 0.01774427, 0.02070771,
#        0.02338026, 0.02255607, 0.01804122, 0.02235002, 0.01810788,
#        0.03401591, 0.03278568, 0.03439165, 0.03786414, 0.03996702,
#        0.03979128, 0.03914284, 0.0419063 , 0.04450611, 0.04745139,
#        0.05220865, 0.06220192, 0.06235342, 0.0679167 , 0.07207398,
#        0.06492899, 0.06768034, 0.0676258 , 0.07534044, 0.07424353,
#        0.07627369, 0.07992193, 0.08195212, 0.08780021, 0.09206055,
#        0.09329074, 0.09372103, 0.08643668, 0.0846792 , 0.0849398 ,
#        0.09178781, 0.09371498, 0.09785407, 0.10761101, 0.12062833,
#        0.11819212, 0.11819817, 0.12760968, 0.13055493, 0.1284581 ,
#        0.12654309, 0.12454928, 0.13117306, 0.13571824, 0.13762114])]
# [0.1329184100733258]
#
# [array([0.01254461, 0.01388393, 0.01666555, 0.01931386, 0.01890783,
#        0.01982291, 0.01940476, 0.01870178, 0.01774427, 0.02070771,
#        0.02338026, 0.02255607, 0.01804122, 0.02235002, 0.01810788,
#        0.03401591, 0.03278568, 0.03439165, 0.03786414, 0.03996702,
#        0.03979128, 0.03914284, 0.0419063 , 0.04450611, 0.04745139,
#        0.05220865, 0.06220192, 0.06235342, 0.0679167 , 0.07207398,
#        0.06492899, 0.06768034, 0.0676258 , 0.07534044, 0.07424353,
#        0.07627369, 0.07992193, 0.08195212, 0.08780021, 0.09206055,
#        0.09329074, 0.09372103, 0.08643668, 0.0846792 , 0.0849398 ,
#        0.09178781, 0.09371498, 0.09785407, 0.10761101, 0.12062833,
#        0.11819212, 0.11819817, 0.12760968, 0.13055493, 0.1284581 ,
#        0.12654309, 0.12454928, 0.13117306, 0.13571824, 0.13762114]), array([0.01388393, 0.01666555, 0.01931386, 0.01890783, 0.01982291,
#        0.01940476, 0.01870178, 0.01774427, 0.02070771, 0.02338026,
#        0.02255607, 0.01804122, 0.02235002, 0.01810788, 0.03401591,
#        0.03278568, 0.03439165, 0.03786414, 0.03996702, 0.03979128,
#        0.03914284, 0.0419063 , 0.04450611, 0.04745139, 0.05220865,
#        0.06220192, 0.06235342, 0.0679167 , 0.07207398, 0.06492899,
#        0.06768034, 0.0676258 , 0.07534044, 0.07424353, 0.07627369,
#        0.07992193, 0.08195212, 0.08780021, 0.09206055, 0.09329074,
#        0.09372103, 0.08643668, 0.0846792 , 0.0849398 , 0.09178781,
#        0.09371498, 0.09785407, 0.10761101, 0.12062833, 0.11819212,
#        0.11819817, 0.12760968, 0.13055493, 0.1284581 , 0.12654309,
#        0.12454928, 0.13117306, 0.13571824, 0.13762114, 0.13291841])]
# [0.1329184100733258, 0.12667035217394387]

# %% [markdown]
# #### Convert x_train and y_train to numpy arrays

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %% [markdown]
# #### Reshape the data

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (1549, 60, 1)

# %% [markdown]
# #### Build the LSTM Model

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape  = (x_train.shape[1], 1), ))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))

# %% [markdown]
# #### Compile the model

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# #### Train the model

# %%
model.fit(x_train, y_train, batch_size = 1, epochs = 1)
# Out:
# 1549/1549 [==============================] - 28s 18ms/step - loss: 8.9657e-04

# %% [markdown]
# #### Create the testing dataset

# %%
test_data = scaled_data[training_data_len-60: ,:]

# %% [markdown]
# #### Create x_test and y_test

# %%
x_test = []
y_test = dataset[training_data_len: , :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %% [markdown]
# #### Convert data into numpy array

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# #### Get the model's predicted price value

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %% [markdown]
# #### Get Root Mean Squared Error RMSE

# %%
rmse = np.sqrt(np.mean(predictions - y_test) ** 2)
rmse
# Out:
# 1.7889805029873824

# %% [markdown]
# ### Plot the data

# %%
train = data[: training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Out:
# <ipython-input-18-fac123c220ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %% [markdown]
# #### Visualize the data

# %%
plt.figure(figsize = (16, 8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price $', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc = 'lower right')
plt.show()
